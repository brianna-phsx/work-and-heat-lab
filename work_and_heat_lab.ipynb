# %% [markdown]
# <a href="https://colab.research.google.com/github/brianna-phsx/work-and-heat-lab/blob/main/work_and_heat_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#RUN THIS CELL TO CONVERT TEMPERATURES TO RESISTANCES (BEFORE PERFORMING THE EXPERIMENT)

import numpy as np

resistance=np.array([351020,332640,315320,298990,283600,269080,255380,242460,230260,218730,207850,197560,187840,178650,169950,161730,153950,146580,139610,133000,126740,120810,115190,109850,104800,
                     100000,95447,91126,87022,83124,79422,75903,72560,69380,66356,63480,60743,58138,55658,53297,51048,48905,46863,44917,43062,41292,39605,37995,36458,34991,33591,32253,30976,29756,
                     28590,27475,26409,25390,24415,23483,22590,21736,20919,20136,19386,18668,17980,17321,16689,16083,15502,14945,14410,13897,13405,12932,12479,12043,11625,11223,10837,10467,10110,
                     9767.2,9437.7,9120.8,8816.0,8522.7,8240.6,7969.1,7707.7,7456.2,7214.0,6980.6,6755.9,6539.4,6330.8,6129.8,5936.1,5749.3,5569.3]) #ohms
temperature=np.arange(0,101,1) #degrees celsius

T_cold=input('\nTEMPERATURES:\n\nT_cold [deg C] = ')
T_hot=input('T_hot  [deg C] = ')

R_cold,R_hot=np.interp([T_cold,T_hot],temperature,resistance,left=0,right=0)

if R_room==0 or R_cold==0 or R_hot==0:
  print('\nInvalid temperature(s) entered, try again')
else:
  print('\nRESISTANCES:\n\nR_cold ={:7.0f} Ohms\nR_hot  ={:7.0f} Ohms\n'.format(R_cold,R_hot))

# %%
#RUN THIS CELL TO CONVERT RESISTANCES TO TEMPERATURES (AFTER PERFORMING THE EXPERIMENT)

import numpy as np

resistance=np.array([351020,332640,315320,298990,283600,269080,255380,242460,230260,218730,207850,197560,187840,178650,169950,161730,153950,146580,139610,133000,126740,120810,115190,109850,104800,
                     100000,95447,91126,87022,83124,79422,75903,72560,69380,66356,63480,60743,58138,55658,53297,51048,48905,46863,44917,43062,41292,39605,37995,36458,34991,33591,32253,30976,29756,
                     28590,27475,26409,25390,24415,23483,22590,21736,20919,20136,19386,18668,17980,17321,16689,16083,15502,14945,14410,13897,13405,12932,12479,12043,11625,11223,10837,10467,10110,
                     9767.2,9437.7,9120.8,8816.0,8522.7,8240.6,7969.1,7707.7,7456.2,7214.0,6980.6,6755.9,6539.4,6330.8,6129.8,5936.1,5749.3,5569.3]) #ohms
resistance=np.flip(resistance)
temperature=np.arange(100,-1,-1) #degrees celsius


R_i=int(input('\nRESISTANCES:\n\nR_i [Ohms] = '))
R_f=int(input('R_f [Ohms] = '))

T_i,T_f=np.interp([R_i,R_f],resistance,temperature,left=0,right=0)

if T_i==0 or T_f==0:
  print('\nInvalid resistance(s) entered, try again')
else:
  print('\nTEMPERATURES:\n\nT_i = {:4.1f} deg C\nT_f = {:4.1f} deg C\n'.format(T_i,T_f))
